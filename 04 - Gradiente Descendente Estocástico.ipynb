# %% [markdown]
# ## Gradiente Descendente Estocástico

# %% [markdown]
# ### Diferencias clave con el gradiente descendente clásico
# * Se actualizan los parámetros por cada punto de entrenamiento, no por el conjunto completo.
# * Se barajan los datos en cada época, lo que mejora la convergencia.
# * SGD es útil cuando tienes grandes volúmenes de datos, ya que permite comenzar a aprender desde el primer ejemplo.

# %% [markdown]
# ## Problema
# Ajustar una línea recta $𝑦=𝑤𝑥+𝑏$ a un conjunto de datos, minimizando el error cuadrático medio (MSE) entre las predicciones y los valores reales.

# %% [markdown]
# ### Importar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Datos sintéticos con ruido

# %%
np.random.seed(42)
x = np.linspace(0, 10, 150)
y = 2.5 * x + 1.0 + np.random.normal(0, 2, size=x.shape)

# %% [markdown]
# ### Parámetros de entrenamiento

# %%
learning_rate = 0.01
epochs = 10  # se recorren todos los datos varias veces
w = 0.0  # pendiente (peso)
b = 0.0  # sesgo
n = len(x)
losses = []

# %% [markdown]
# ### Entrenamiento con gradiente descendente estocástico (SGD)

# %%
for epoch in range(epochs):
    indices = np.random.permutation(n)  # Se barajan aleatoriamente los índices de los datos en cada época (importante en SGD)

    for i in indices:  # Se recorre cada muestra individualmente (uno por uno)
        xi = x[i]      # Entrada i-ésima
        yi = y[i]      # Salida/valor real correspondiente

        # Predicción con los parámetros actuales
        y_pred = w * xi + b
        error = y_pred - yi  # Error entre la predicción y el valor real

        # Derivadas del error cuadrático con respecto a w y b para un solo ejemplo
        dw = 2 * xi * error
        db = 2 * error

        # Actualización de los parámetros (peso y sesgo)
        w -= learning_rate * dw
        b -= learning_rate * db

    # Calcular y guardar pérdida (MSE) al final de cada época
    y_pred_total = w * x + b
    loss = np.mean((y_pred_total - y) ** 2)
    losses.append(loss)
    print(f"Época {epoch+1}: w = {w:.4f}, b = {b:.4f}, Loss = {loss:.4f}")

# Mostrar modelo final
print(f"\nModelo final: y = {w:.4f}x + {b:.4f}")

# %% [markdown]
# ### Graficar resultados

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.scatter(x, y, label="Datos reales", alpha=0.7)
plt.plot(x, w * x + b, color="red", label="Modelo ajustado (SGD)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Regresión lineal con Gradiente Descendente Estocástico")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(1, epochs + 1), losses, marker='o')
plt.xlabel("Época")
plt.ylabel("Pérdida (MSE)")
plt.title("Evolución del error")
plt.grid(True)

plt.tight_layout()
plt.show()
